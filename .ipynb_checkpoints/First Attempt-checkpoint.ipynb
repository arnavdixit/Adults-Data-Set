# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
dataset = pd.read_csv('adult.csv')

# %%
dataset.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status           ocupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# ocupation         32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Target            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dataset.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
sns.displot(data=dataset,x = 'age',kde=True,bins=20)

# %%
dataset.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# ocupation         0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Target            0
# dtype: int64

# %%
dataset['Target'] = dataset.loc[:,'Target'].apply(lambda x: 0 if x == ' <=50K' else '1')
dataset['Target'] = dataset['Target'].astype(int)

# %%
dataset.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status           ocupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Target
# 0          2174             0              40   United-States       0
# ...

# %%
plt.figure(figsize=(12,8))
corr = dataset.corr()
sns.heatmap(data=corr,annot=True,cmap='viridis', )

# %%
dataset['age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
dataset.drop(['education','relationship'], axis=1, inplace=True)

# %%
dataset[dataset['age']<=24].count()
# Out:
# age               5570
# workclass         5570
# fnlwgt            5570
# education-num     5570
# marital-status    5570
# ocupation         5570
# race              5570
# sex               5570
# capital-gain      5570
# capital-loss      5570
# hours-per-week    5570
# native-country    5570
# Target            5570
# dtype: int64

# %%
dataset[(dataset['age']<=30) & (dataset['age']>=25)].count()
# Out:
# age               5002
# workclass         5002
# fnlwgt            5002
# education-num     5002
# marital-status    5002
# ocupation         5002
# race              5002
# sex               5002
# capital-gain      5002
# capital-loss      5002
# hours-per-week    5002
# native-country    5002
# Target            5002
# dtype: int64

# %%
dataset[(dataset['age']<=36) & (dataset['age']>=31)].count()
# Out:
# age               5251
# workclass         5251
# fnlwgt            5251
# education-num     5251
# marital-status    5251
# ocupation         5251
# race              5251
# sex               5251
# capital-gain      5251
# capital-loss      5251
# hours-per-week    5251
# native-country    5251
# Target            5251
# dtype: int64

# %%
dataset[(dataset['age']<=43) & (dataset['age']>=37)].count()
# Out:
# age               5653
# workclass         5653
# fnlwgt            5653
# education-num     5653
# marital-status    5653
# ocupation         5653
# race              5653
# sex               5653
# capital-gain      5653
# capital-loss      5653
# hours-per-week    5653
# native-country    5653
# Target            5653
# dtype: int64

# %%
dataset[(dataset['age']<=52) & (dataset['age']>=44)].count()
# Out:
# age               5698
# workclass         5698
# fnlwgt            5698
# education-num     5698
# marital-status    5698
# ocupation         5698
# race              5698
# sex               5698
# capital-gain      5698
# capital-loss      5698
# hours-per-week    5698
# native-country    5698
# Target            5698
# dtype: int64

# %%
dataset[(dataset['age']<=100) & (dataset['age']>=53)].count()
# Out:
# age               5387
# workclass         5387
# fnlwgt            5387
# education-num     5387
# marital-status    5387
# ocupation         5387
# race              5387
# sex               5387
# capital-gain      5387
# capital-loss      5387
# hours-per-week    5387
# native-country    5387
# Target            5387
# dtype: int64

# %%
dataset.loc[ dataset['age'] <= 24, 'age'] = 0
dataset.loc[(dataset['age'] >= 25) & (dataset['age'] <= 30), 'age'] = 1
dataset.loc[(dataset['age'] >= 31) & (dataset['age'] <= 36), 'age'] = 2
dataset.loc[(dataset['age'] >= 37) & (dataset['age'] <= 43), 'age'] = 3
dataset.loc[(dataset['age'] >= 44) & (dataset['age'] <= 52), 'age'] = 4
dataset.loc[ dataset['age'] >= 53, 'age'] = 5

# %%
dataset.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0    3          State-gov   77516             13        Never-married
# 1    4   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2    3            Private  215646              9             Divorced
# 3    5            Private  234721              7   Married-civ-spouse
# 4    1            Private  338409             13   Married-civ-spouse
#
#             ocupation    race      sex  capital-gain  capital-loss  \
# 0        Adm-clerical   White     Male          2174             0
# 1     Exec-managerial   White     Male             0             0
# 2   Handlers-cleaners   White     Male             0             0
# 3   Handlers-cleaners   Black     Male             0             0
# 4      Prof-specialty   Black   Female             0             0
#
#    hours-per-week  native-country  Target
# 0              40   United-States       0
# 1              13   United-States       0
# ...

# %%
sns.displot(data=dataset,x='capital-gain',kde=True,bins=20,aspect=1.6)

# %%
sns.displot(data=dataset,x='fnlwgt',kde=True,bins=20,aspect=1.6)

# %%
sns.displot(data=dataset,x='capital-loss',kde=True,bins=20,aspect=1.6)

# %%
sns.displot(data=dataset,x='hours-per-week',kde=True,bins=20,aspect=1.6)

# %%
sns.displot(data=dataset,x='education-num',kde=True,bins=20,aspect=1.6)

# %%
dataset['hours-per-week'].unique()
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95], dtype=int64)

# %%
sex_map = {' Female':0,' Male':1}
dataset['sex'] = dataset['sex'].map(sex_map)

# %%
dataset.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0    3          State-gov   77516             13        Never-married
# 1    4   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2    3            Private  215646              9             Divorced
# 3    5            Private  234721              7   Married-civ-spouse
# 4    1            Private  338409             13   Married-civ-spouse
#
#             ocupation    race  sex  capital-gain  capital-loss  \
# 0        Adm-clerical   White    1          2174             0
# 1     Exec-managerial   White    1             0             0
# 2   Handlers-cleaners   White    1             0             0
# 3   Handlers-cleaners   Black    1             0             0
# 4      Prof-specialty   Black    0             0             0
#
#    hours-per-week  native-country  Target
# 0              40   United-States       0
# 1              13   United-States       0
# ...

# %%
dataset['workclass'] = dataset['workclass'].str.replace(" ","")
dataset['marital-status'] = dataset['marital-status'].str.replace(" ","")
dataset['ocupation'] = dataset['ocupation'].str.replace(" ","")
dataset['race'] = dataset['race'].str.replace(" ","")
dataset['native-country'] = dataset['native-country'].str.replace(" ","")

# %%
race_map = {'White':0,'Black':1,'Asian-Pac-Islander':3,'Amer-Indian-Eskimo':3,'Other':3}
dataset['race'] = dataset['race'].map(race_map)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 13 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# ocupation         32561 non-null object
# race              32561 non-null int64
# sex               32561 non-null int64
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Target            32561 non-null int32
# dtypes: int32(1), int64(8), object(4)
# memory usage: 3.1+ MB

# %%
(dataset['workclass'].value_counts()/dataset['workclass'].count())*100
# Out:
# Private             69.703019
# Self-emp-not-inc     7.803814
# Local-gov            6.427935
# ?                    5.638647
# State-gov            3.986364
# Self-emp-inc         3.427413
# Federal-gov          2.948312
# Without-pay          0.042996
# Never-worked         0.021498
# Name: workclass, dtype: float64

# %%
(dataset['ocupation'].value_counts()/dataset['ocupation'].count())*100
# Out:
# Prof-specialty       12.714597
# Craft-repair         12.588680
# Exec-managerial      12.487331
# Adm-clerical         11.578268
# Sales                11.209729
# Other-service        10.119468
# Machine-op-inspct     6.148460
# ?                     5.660146
# Transport-moving      4.904641
# Handlers-cleaners     4.207487
# Farming-fishing       3.052732
# Tech-support          2.850035
# Protective-serv       1.993182
# Priv-house-serv       0.457603
# Armed-Forces          0.027640
# Name: ocupation, dtype: float64

# %%
country_perc = (dataset['native-country'].value_counts()/dataset['native-country'].count())*100

# %%
y = dataset.loc[:,'Target']

# %%
dataset = dataset.drop('Target',axis=1)

# %%
dataset.head()
# Out:
#    age         workclass  fnlwgt  education-num      marital-status  \
# 0    3         State-gov   77516             13       Never-married
# 1    4  Self-emp-not-inc   83311             13  Married-civ-spouse
# 2    3           Private  215646              9            Divorced
# 3    5           Private  234721              7  Married-civ-spouse
# 4    1           Private  338409             13  Married-civ-spouse
#
#            ocupation  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0       Adm-clerical     0    1          2174             0              40
# 1    Exec-managerial     0    1             0             0              13
# 2  Handlers-cleaners     0    1             0             0              40
# 3  Handlers-cleaners     1    1             0             0              40
# 4     Prof-specialty     1    0             0             0              40
#
#   native-country
# 0  United-States
# 1  United-States
# 2  United-States
# 3  United-States
# ...

# %%
dataset.loc[ dataset['workclass'] == '?', 'workclass'] = 'Others'

# %%
dataset.loc[ dataset['workclass'] == 'Without-pay', 'workclass'] = 'Others'
dataset.loc[ dataset['workclass'] == 'Never-worked', 'workclass'] = 'Others'

# %%
dataset['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Others               1857
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Name: workclass, dtype: int64

# %%
dataset.loc[ dataset['ocupation'] == '?', 'ocupation'] = 'Others'
dataset.loc[ dataset['ocupation'] == 'Armed-Forces', 'ocupation'] = 'Others'

# %%
dataset.loc[ dataset['native-country'] == '?', 'native-country'] = 'Others'

# %%
dataset.loc[ dataset['native-country'] == 'Peru', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Greece', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'France', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Ecuador', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Ireland', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Hong', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Trinadad&Tobago', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Cambodia', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Thailand', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Laos', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Yugoslavia', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Outlying-US(Guam-USVI-etc)', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Honduras', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Hungary', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Scotland', 'native-country'] = 'Others'
dataset.loc[ dataset['native-country'] == 'Holand-Netherlands', 'native-country'] = 'Others'

# %%
dataset.groupby('native-country').count()
# Out:
#                               age  workclass  fnlwgt  education-num  \
# native-country
# Cambodia                       19         19      19             19
# Canada                        121        121     121            121
# China                          75         75      75             75
# Columbia                       59         59      59             59
# Cuba                           95         95      95             95
# Dominican-Republic             70         70      70             70
# Ecuador                        28         28      28             28
# El-Salvador                   106        106     106            106
# England                        90         90      90             90
# France                         29         29      29             29
# Germany                       137        137     137            137
# Greece                         29         29      29             29
# Guatemala                      64         64      64             64
# ...

# %%
dataset.sum()
# Out:
# age                                                           82190
# workclass         State-govSelf-emp-not-incPrivatePrivatePrivate...
# fnlwgt                                                   6179373392
# education-num                                                328237
# marital-status    Never-marriedMarried-civ-spouseDivorcedMarried...
# ocupation         Adm-clericalExec-managerialHandlers-cleanersHa...
# race                                                           7987
# sex                                                           21790
# capital-gain                                               35089324
# capital-loss                                                2842700
# hours-per-week                                              1316684
# native-country    United-StatesUnited-StatesUnited-StatesUnited-...
# dtype: object
